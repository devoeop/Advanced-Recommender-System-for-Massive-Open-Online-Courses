# %% [markdown]
# # **Clustering based Course Recommender System**

# %% [markdown]
# We have generated user profile vectors based on course ratings and genres.
#
# A user profile vector may look like a row vector in the following matrix, for example, we can see the Database column for user2 has a value 1 which means user2 is very interesting in courses related to the databases. With the user profile vectors generated, we can also easily compute the similarity among users based on their shared interests.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles.png)

# %% [markdown]
# Furthermore, we could perform clustering algorithms such as K-means or DBSCAN to group users with similar learning interests. For example, in the below user clusters, we have user clusters whom have learned courses related to machine learning, cloud computing, databases, and web development, etc.

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/userprofiles_clustering.png)

# %% [markdown]
# For each user group, we can come up with a list of popular courses. For example, for the machine learning user cluster/learning group, we can count the most frequently enrolled courses, which are very likely to be the most popular and good machine learning courses because they are enrolled by many users who are interested in machine learning.
#
# If we know a user belongs to the machine learning group, we may recommend the most enrolled courses to them and it is very likely the user will be interested in them.

# %% [markdown]
# ## Objectives

# %% [markdown]
# * Perform k-means clustering on the original user profile feature vectors
# * Apply PCA (Principle Component Analysis ) on user profile feature vectors to reduce dimensions
# * Perform k-means clustering on the PCA transformed main components
# * Generate course recommendations based on other group members' enrollment history

# %% [markdown]
# ----

# %% [markdown]
# First install and import required libraries:

# %%
# !pip install scikit-learn==1.0.2
# !pip install seaborn==0.11.1
# Out:
# Requirement already satisfied: scikit-learn==1.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (1.21.6)
# Requirement already satisfied: scipy>=1.1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from scikit-learn==1.0.2) (3.1.0)
# Requirement already satisfied: seaborn==0.11.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (0.11.1)
# Requirement already satisfied: numpy>=1.15 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.21.6)
# Requirement already satisfied: scipy>=1.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.7.3)
# Requirement already satisfied: pandas>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (1.3.5)
# Requirement already satisfied: matplotlib>=2.2 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from seaborn==0.11.1) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (8.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from matplotlib>=2.2->seaborn==0.11.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from pandas>=0.23->seaborn==0.11.1) (2023.3)
# Requirement already satisfied: typing-extensions in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=2.2->seaborn==0.11.1) (4.5.0)
# Requirement already satisfied: six>=1.5 in /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.1) (1.16.0)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %matplotlib inline

# %%
# also set a random state
rs = 123

# %% [markdown]
# ### Load the user profile dataset

# %% [markdown]
# Let's first load the original user profile feature vectors:

# %%
user_profile_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/user_profile.csv"
user_profile_df = pd.read_csv(user_profile_url)
user_profile_df.head()
# Out:
#    user  Database  Python  CloudComputing  DataAnalysis  Containers  \
# 0     2      52.0    14.0             6.0          43.0         3.0
# 1     4      40.0     2.0             4.0          28.0         0.0
# 2     5      24.0     8.0            18.0          24.0         0.0
# 3     7       2.0     0.0             0.0           2.0         0.0
# 4     8       6.0     0.0             0.0           4.0         0.0
#
#    MachineLearning  ComputerVision  DataScience  BigData  Chatbot     R  \
# 0             33.0             0.0         29.0     41.0      2.0  18.0
# 1             14.0             0.0         20.0     24.0      0.0   6.0
# 2             30.0             0.0         22.0     14.0      2.0  14.0
# 3              0.0             0.0          0.0      2.0      0.0   0.0
# 4              0.0             0.0          0.0      6.0      0.0   2.0
#
#    BackendDev  FrontendDev  Blockchain
# 0        34.0          9.0         6.0
# 1         6.0          0.0         2.0
# 2        26.0          4.0         6.0
# 3         0.0          0.0         0.0
# 4         0.0          0.0         0.0

# %%
user_profile_df.shape
# Out:
# (33901, 15)

# %% [markdown]
# we can then list the feature names, they are the user interested topics (course genres):

# %%
feature_names = list(user_profile_df.columns[1:])
feature_names
# Out:
# ['Database',
#  'Python',
#  'CloudComputing',
#  'DataAnalysis',
#  'Containers',
#  'MachineLearning',
#  'ComputerVision',
#  'DataScience',
#  'BigData',
#  'Chatbot',
#  'R',
#  'BackendDev',
#  'FrontendDev',
#  'Blockchain']

# %% [markdown]
# As we can see from the user profile dataset, we have about 33K unique users with interests in areas like ``Database``, ``Python``, ``CloudComputing``, etc. Then, let's check the  summary statistics for each feature.

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  33901.000000  33901.000000    33901.000000  33901.000000
# mean   1.064064e+06      5.518569      3.493791        2.307100      3.624701
# std    4.972578e+05      7.611941      4.227254        3.841858      4.760135
# min    2.000000e+00      0.000000      0.000000        0.000000      0.000000
# 25%    6.813480e+05      0.000000      0.000000        0.000000      0.000000
# 50%    1.043907e+06      3.000000      3.000000        0.000000      3.000000
# 75%    1.451159e+06      9.000000      6.000000        3.000000      6.000000
# max    2.103039e+06     63.000000     18.000000       38.000000     48.000000
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  33901.000000     33901.000000    33901.000000  33901.000000
# mean       0.998938         3.048022        0.001770      5.087343
# std        2.351764         4.624004        0.072846      5.230697
# min        0.000000         0.000000        0.000000      0.000000
# 25%        0.000000         0.000000        0.000000      0.000000
# 50%        0.000000         0.000000        0.000000      3.000000
# 75%        0.000000         3.000000        0.000000      9.000000
# max       15.000000        39.000000        3.000000     32.000000
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  33901.000000  33901.000000  33901.000000  33901.000000  33901.000000
# mean       4.750450      0.462995      1.017433      2.269461      0.315802
# std        7.216228      1.055186      2.342532      4.310752      1.363462
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        2.000000      0.000000      0.000000      0.000000      0.000000
# 75%        6.000000      0.000000      0.000000      3.000000      0.000000
# max       54.000000      6.000000     18.000000     54.000000     15.000000
#
#          Blockchain
# count  33901.000000
# mean       0.986844
# std        1.950585
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        2.000000
# max       12.000000

# %% [markdown]
# The original user profile feature vector is not normalized, which may cause issues when we perform clustering and Principal component analysis (PCA), therefor we standardize the data.

# %%
# Use StandardScaler to make each feature with mean 0, standard deviation 1
scaler = StandardScaler()
user_profile_df[feature_names] = scaler.fit_transform(user_profile_df[feature_names])
print("mean {} and standard deviation{} ".format(user_profile_df[feature_names].mean(),user_profile_df[feature_names].std()))
# Out:
# mean Database          -2.217793e-14
# Python             7.204451e-14
# CloudComputing    -3.443061e-14
# DataAnalysis      -2.543096e-15
# Containers         2.028543e-14
# MachineLearning   -1.199377e-14
# ComputerVision     3.136613e-15
# DataScience        5.723643e-15
# BigData           -4.646660e-15
# Chatbot            1.207204e-14
# R                 -5.597167e-15
# BackendDev        -7.880864e-15
# FrontendDev       -2.312337e-14
# Blockchain         4.286451e-14
# dtype: float64 and standard deviationDatabase           1.000015
# Python             1.000015
# CloudComputing     1.000015
# DataAnalysis       1.000015
# Containers         1.000015
# MachineLearning    1.000015
# ComputerVision     1.000015
# DataScience        1.000015
# BigData            1.000015
# Chatbot            1.000015
# R                  1.000015
# BackendDev         1.000015
# FrontendDev        1.000015
# Blockchain         1.000015
# dtype: float64

# %%
user_profile_df.describe()
# Out:
#                user      Database        Python  CloudComputing  DataAnalysis  \
# count  3.390100e+04  3.390100e+04  3.390100e+04    3.390100e+04  3.390100e+04
# mean   1.064064e+06 -2.217793e-14  7.204451e-14   -3.443061e-14 -2.543096e-15
# std    4.972578e+05  1.000015e+00  1.000015e+00    1.000015e+00  1.000015e+00
# min    2.000000e+00 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 25%    6.813480e+05 -7.249991e-01 -8.265040e-01   -6.005256e-01 -7.614816e-01
# 50%    1.043907e+06 -3.308757e-01 -1.168130e-01   -6.005256e-01 -1.312380e-01
# 75%    1.451159e+06  4.573712e-01  5.928781e-01    1.803581e-01  4.990056e-01
# max    2.103039e+06  7.551593e+00  3.431642e+00    9.290667e+00  9.322416e+00
#
#          Containers  MachineLearning  ComputerVision   DataScience  \
# count  3.390100e+04     3.390100e+04    3.390100e+04  3.390100e+04
# mean   2.028543e-14    -1.199377e-14    3.136613e-15  5.723643e-15
# std    1.000015e+00     1.000015e+00    1.000015e+00  1.000015e+00
# min   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 25%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -9.726080e-01
# 50%   -4.247674e-01    -6.591835e-01   -2.429612e-02 -3.990622e-01
# 75%   -4.247674e-01    -1.038556e-02   -2.429612e-02  7.480294e-01
# max    5.953517e+00     7.775190e+00    4.115884e+01  5.145214e+00
#
#             BigData       Chatbot             R    BackendDev   FrontendDev  \
# count  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04  3.390100e+04
# mean  -4.646660e-15  1.207204e-14 -5.597167e-15 -7.880864e-15 -2.312337e-14
# std    1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00  1.000015e+00
# min   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 25%   -6.583107e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 50%   -3.811535e-01 -4.387873e-01 -4.343370e-01 -5.264730e-01 -2.316212e-01
# 75%    1.731609e-01 -4.387873e-01 -4.343370e-01  1.694715e-01 -2.316212e-01
# max    6.824934e+00  5.247500e+00  7.249771e+00  1.200053e+01  1.076995e+01
#
#          Blockchain
# count  3.390100e+04
# mean   4.286451e-14
# std    1.000015e+00
# min   -5.059295e-01
# 25%   -5.059295e-01
# 50%   -5.059295e-01
# 75%    5.194189e-01
# max    5.646161e+00

# %% [markdown]
# The normalized user profile features are:

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
features
# Out:
#        Database    Python  CloudComputing  DataAnalysis  Containers  \
# 0      6.106474  2.485388        0.961242      8.272010    0.850889
# 1      4.529980 -0.353377        0.440653      5.120792   -0.424767
# 2      2.427988  1.066006        4.084776      4.280467   -0.424767
# 3     -0.462250 -0.826504       -0.600526     -0.341319   -0.424767
# 4      0.063248 -0.826504       -0.600526      0.078843   -0.424767
# ...         ...       ...             ...           ...         ...
# 33896 -0.330876 -0.116813        0.180358      0.499006   -0.424767
# 33897 -0.724999 -0.826504       -0.079936     -0.761482   -0.424767
# 33898 -0.330876  0.592878        0.961242     -0.761482   -0.424767
# 33899 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
# 33900 -0.724999 -0.826504       -0.600526     -0.761482   -0.424767
#
#        MachineLearning  ComputerVision  DataScience   BigData   Chatbot  \
# 0             6.477594       -0.024296     4.571668  5.023412  1.456642
# 1             2.368540       -0.024296     2.851031  2.667576 -0.438787
# 2             5.828796       -0.024296     3.233395  1.281790  1.456642
# 3            -0.659184       -0.024296    -0.972608 -0.381153 -0.438787
# 4            -0.659184       -0.024296    -0.972608  0.173161 -0.438787
# ...                ...             ...          ...       ...       ...
# 33896        -0.659184       -0.024296     0.174484 -0.658311 -0.438787
# 33897        -0.659184       -0.024296    -0.972608 -0.658311 -0.438787
# 33898         2.368540       -0.024296     0.748029 -0.658311 -0.438787
# 33899        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
# 33900        -0.226652       -0.024296    -0.972608 -0.658311 -0.438787
#
#               R  BackendDev  FrontendDev  Blockchain
# 0      7.249771    7.360899     6.369323    2.570116
# 1      2.127032    0.865416    -0.231621    0.519419
# 2      5.542191    5.505047     2.702132    2.570116
# 3     -0.434337   -0.526473    -0.231621   -0.505930
# 4      0.419453   -0.526473    -0.231621   -0.505930
# ...         ...         ...          ...         ...
# 33896  2.127032    0.865416    -0.231621    1.032093
# 33897 -0.434337   -0.526473    -0.231621   -0.505930
# 33898  0.846348   -0.526473    -0.231621   -0.505930
# 33899 -0.434337   -0.526473    -0.231621   -0.505930
# 33900 -0.434337   -0.526473    -0.231621   -0.505930
#
# [33901 rows x 14 columns]

# %% [markdown]
# we can also save the user ids for later recommendation tasks:

# %%
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
user_ids
# Out:
#           user
# 0            2
# 1            4
# 2            5
# 3            7
# 4            8
# ...        ...
# 33896  2102054
# 33897  2102356
# 33898  2102680
# 33899  2102983
# 33900  2103039
#
# [33901 rows x 1 columns]

# %% [markdown]
# ### Perform K-means clustering algorithm on the user profile feature vectors

# %% [markdown]
# With the user profile dataset ready, you need to use the `KMeans` class provided by scikit-learn library to perform clustering on the user profile feature vectors.

# %% [markdown]
# For `KMeans` algorithm, one important hyperparameter is the number of clusters `n_cluster`, and a good way to find the optimized `n_cluster` is using to grid search a list of candidates and find the one with the best or optimized clustering evaluation metrics such as minimal `sum of squared distance`:

# %%
# Find an optimized number of neighors k from a candidate list such as list_k = list(range(1, 30))
list_k = list(range(1, 30))

# List to hold the sum of square distances for each fitted model
sum_of_squares = []

# Grid search for the optimized number of clusters
for k in list_k:
    model = KMeans(n_clusters=k, random_state=rs)
    model.fit(features)
    sum_of_squares.append(model.inertia_)

# Plotting the sum of square distances against the number of clusters
plt.plot(list_k, sum_of_squares, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Sum of Square Distances')
plt.title('Elbow Method for Optimal k')
plt.show()

# %% [markdown]
# From the elbow plot, we should visually identify the point where the metric starting to be flatten, which indicates the optimized number of clusters.

# %% [markdown]
# Once we have identified the best number of clusters, we can apply `KMeans()` again to generate cluster label for all users.

# %%
cluster_labels = [None] * len(user_ids)

# %%
optimal_k = 20

# Apply KMeans with the optimized number of clusters
model = KMeans(n_clusters=optimal_k, random_state=rs)
model.fit(features)

# Get the cluster labels for all users
cluster_labels = model.labels_

# %%
cluster_labels
# Out:
# array([18, 17, 18, ...,  2,  6,  6], dtype=int32)

# %% [markdown]
# The cluster labels we generated is a list of integers indicating cluster indices. We may use the following utility method to combine the cluster labels and user ids to a dataframe, so that you know which cluster a user belongs:

# %%
def combine_cluster_labels(user_ids, labels):
    labels_df = pd.DataFrame(labels)
    cluster_df = pd.merge(user_ids, labels_df, left_index=True, right_index=True)
    cluster_df.columns = ['user', 'cluster']
    return cluster_df

# %%
cluster_df = combine_cluster_labels(user_ids, cluster_labels)
display(cluster_df)
# Out:
#           user  cluster
# 0            2       18
# 1            4       17
# 2            5       18
# 3            7        6
# 4            8        6
# ...        ...      ...
# 33896  2102054       12
# 33897  2102356        6
# 33898  2102680        2
# 33899  2102983        6
# 33900  2103039        6
#
# [33901 rows x 2 columns]

# %% [markdown]
# Now, each user finds its own cluster or we can say we have created many clusters of learning communities. Learners within each community share very similar learning interests.

# %% [markdown]
# ### Apply PCA on user profile feature vectors to reduce dimensions

# %% [markdown]
# In the previous step, we applied `KMeans` on the original user profile feature vectors which have 14 original features (the course genres).

# %%
features = user_profile_df.loc[:, user_profile_df.columns != 'user']
user_ids = user_profile_df.loc[:, user_profile_df.columns == 'user']
feature_names = list(user_profile_df.columns[1:])

# %%
print(f"There are {len(feature_names)} features for each user profile.")
# Out:
# There are 14 features for each user profile.

# %% [markdown]
# If we plot a covariance matrix of the user profile feature vectors with 14 features, we can observe that some features are actually correlated:

# %%
sns.set_theme(style="white")

# Compute the correlation matrix
corr = features.cov()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})


plt.show()

# %% [markdown]
# For example, the feature `MachineLearning` and the feature `DataScience` are correlated. Such covariances among features may indicate that we can apply PCA to find its main components (eigenvectors with max eigenvalues on the covariance matrix).
#
# If we only keep the independent main components, then we can reduce the dimensions of our user profile feature vectors.

# %% [markdown]
# Now let's apply the `PCA()` provided by  `scikit-learn` to find the main components in user profile feature vectors and see if we can reduce its dimensions by only keeping the main components.

# %% [markdown]
# Note that when calling the  `PCA()` class, there is also an import argument called `n_components` which indicates how many components you want to keep in the PCA result. One way to find an optimized `n_components` is to do a grid search on a list of argument candidates (such as `range(1, 15)`) and calculate the ratio of the accumulated variance for each candidate.
#
# If the accumulated variances ratio of a candidate `n_components` is larger than a threshold, e.g., 90%, then we can say the transformed `n_components` could explain about 90% of variances of the original data variance and can be considered as an optimized components size.

# %%
# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio

list_components = list(range(1, 15))

# Find the optimized number of components
for component in list_components:
    pca = PCA(n_components=component)
    pca.fit_transform(features)
    
    # Calculate the accumulated variance ratio
    accumulated_variance_ratio = np.sum(pca.explained_variance_ratio_)
    
    # Check if accumulated variance ratio is at least 90%
    if accumulated_variance_ratio >= 0.9:
        optimal_n_components = component
        break

print("Optimal number of components:", optimal_n_components)
# Out:
# Optimal number of components: 9

# %% [markdown]
# If we visualize your hyperparameter searching process, we may get a trend line like the following:

# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/module_3/images/pca.png)

# %% [markdown]
# Once we found the optimized `n_component` argument value, we can apply PCA on the user profile feature vectors and reduce the  14 features into  `n_component` features.

# %%
# - For a list of candidate `n_components` arguments such as 1 to 14, find out the minimal `n` that can explain accumulated 90% variances of previous data
# - In the fitted PCA() model, you can find explained_variance_ratio_ and use the sum() function to add them to get the accumulated variance ratio
# - Merge the user ids and transformed features into a new dataframe

pca = PCA(n_components=optimal_n_components)
transformed_data = pca.fit_transform(features)

# Create a DataFrame with the transformed features
transformed_df = pd.DataFrame(data=transformed_data, index=features.index, columns=[f'PC{i}' for i in range(1, optimal_n_components + 1)])

# Merge the user ids and transformed features into a new dataframe
result_df = pd.merge(user_ids, transformed_df, left_index=True, right_index=True)

# Display the result
display(result_df)
# Out:
#           user        PC1       PC2       PC3       PC4       PC5       PC6  \
# 0            2  17.772494  0.200681  1.730609  2.567359 -3.825814  2.707154
# 1            4   7.145199 -2.847481  2.358636 -0.576654  0.398803 -0.134533
# 2            5  11.363270  1.873619 -1.522077  1.076144 -1.711688  0.883212
# 3            7  -1.834033 -0.277462  0.564905  0.053470 -0.064440  0.165757
# 4            8  -1.049125 -0.684767  1.072765  0.006371 -0.005695  0.118686
# ...        ...        ...       ...       ...       ...       ...       ...
# 33896  2102054   0.633824  0.108815 -0.388871 -0.122665 -0.098364  0.358333
# 33897  2102356  -2.095339  0.135058  0.244727 -0.088185  0.025081  0.183641
# 33898  2102680   0.625943 -0.547167 -1.692824 -0.630589  0.166632  0.676244
# 33899  2102983  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
# 33900  2103039  -2.036832 -0.153534  0.162852  0.082651 -0.126419  0.255109
#
#             PC7       PC8       PC9
# 0      0.681042  2.312613  0.868272
# 1      0.549769  0.469033  0.033405
# 2      1.677582  2.937669  2.097639
# 3      0.030956  0.039519  0.210887
# 4      0.118559  0.559292  0.186379
# ...         ...       ...       ...
# 33896  1.752049  1.486542 -0.523600
# 33897  0.046413  0.191709  0.260437
# 33898 -0.055100  0.582091  1.703193
# 33899  0.072496  0.113750  0.622900
# 33900  0.072496  0.113750  0.622900
#
# [33901 rows x 10 columns]

# %% [markdown]
# ### Perform k-means clustering on the PCA transformed feature vectors

# %% [markdown]
# Now, we have the PCA  components of the original profile vectors. We can perform k-means on them again:

# %%
## - Apply KMeans() on the PCA features
## - Obtain the cluster label lists from model.labels_ attribute
## - Assign each user a cluster label by combining user ids and cluster labels

n_clusters = 15
kmeans = KMeans(n_clusters=n_clusters, random_state=rs)
cluster_labels = kmeans.fit_predict(result_df)

# Assign each user a cluster label
cluster_df['Cluster_new'] = cluster_labels

# Display the result
display(cluster_df)
# Out:
#           user  cluster  Cluster_new
# 0            2       18           12
# 1            4       17           12
# 2            5       18           12
# 3            7        6           12
# 4            8        6           12
# ...        ...      ...          ...
# 33896  2102054       12            3
# 33897  2102356        6            3
# 33898  2102680        2            3
# 33899  2102983        6            3
# 33900  2103039        6            3
#
# [33901 rows x 3 columns]

# %% [markdown]
# Great, now all users find their learning interest groups, either based on their original or the PCA transformed user profile features.

# %% [markdown]
# When a user is in a group or a community, it is very likely that the user will be interested in the courses enrolled by other members within the same group.

# %% [markdown]
# ### Generate course recommendations based on the popular courses in the same cluster

# %% [markdown]
# The Intuition of clustering-based course recommendation is very simple and can be illustrated via the following example:

# %% [markdown]
# Suppose a user has joined a machine learning group (via clustering algorithm). In the group, he/she finds that the top-3 courses enrolled by all other group members are `Machine Learning for Everyone`, `Machine Learning with Python`, `Machine Learning with Scikit-learn`. Since the user has already completed the `Machine Learning for Everyone` earlier, he/she decides to trust the group members' choices and enroll in other two unselected courses `Machine Learning with Python` and `Machine Learning with Scikit-learn`.

# %% [markdown]
# In summary, the clustering-based recommender system first groups all users based on their profiles, and maintains a popular courses list for each group.
#
# For any group member who needs course recommendations, the algorithm recommends the unselected courses from the popular course lists.

# %% [markdown]
# Next, suppose we have a set of test users, and we want to recommend new courses to them using a clustering-based recommender system:

# %%
test_user_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML321EN-SkillsNetwork/labs/datasets/rs_content_test.csv"
test_users_df = pd.read_csv(test_user_url)[['user', 'item']]
display(test_users_df)
# Out:
#          user       item
# 0     1502801   RP0105EN
# 1     1609720   CNSC02EN
# 2     1347188   CO0301EN
# 3      755067   ML0103EN
# 4      538595   BD0115EN
# ...       ...        ...
# 9397  1385217   EE0101EN
# 9398  1864644   DA0101EN
# 9399   435858  TMP0105EN
# 9400  1888188   DB0101EN
# 9401   708518   RP0101EN
#
# [9402 rows x 2 columns]

# %% [markdown]
# The test users dataset has only two columns, the user id and the enrolled course id.

# %% [markdown]
# For each user, let's find its cluster label using the k-means results you have performed in previous steps, assuming it is named `cluster_df`.

# %% [markdown]
# You can assign the cluster label to all test users via merging the clustering labels (`cluster_df`:):

# %%
test_users_labelled = pd.merge(test_users_df, cluster_df, left_on='user', right_on='user')
display(test_users_labelled)
# Out:
#          user      item  cluster  Cluster_new
# 0     1502801  RP0105EN        9           11
# 1     1502801  BD0131EN        9           11
# 2     1502801  BD0212EN        9           11
# 3     1502801  BD0115EN        9           11
# 4     1502801  BD0211EN        9           11
# ...       ...       ...      ...          ...
# 9397   630511  BD0121EN        0           13
# 9398   630511  SC0101EN        0           13
# 9399   630511  BD0111EN        0           13
# 9400   630511  BD0115EN        0           13
# 9401   630511  PY0101EN        0           13
#
# [9402 rows x 4 columns]

# %% [markdown]
# From the above dataframe, we know each user's enrolled courses and its cluster index.

# %% [markdown]
# If we use a `groupby`  and `sum` aggregation, we can get the enrollments count for each course in each group, like the following code snippet:

# %%
courses_cluster = test_users_labelled[['item', 'cluster']]
courses_cluster['count'] = [1] * len(courses_cluster)
courses_cluster = courses_cluster.groupby(['cluster','item']).agg(enrollments = ('count','sum')).reset_index()
courses_cluster
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       cluster      item  enrollments
# 0           0  BC0101EN            6
# 1           0  BD0101EN           99
# 2           0  BD0111EN          105
# 3           0  BD0115EN           62
# 4           0  BD0121EN           22
# ...       ...       ...          ...
# 1204       19  ST0101EN            2
# 1205       19  SW0101EN            1
# 1206       19  SW0201EN            1
# 1207       19    TA0105            1
# 1208       19  TA0106EN            1
#
# [1209 rows x 3 columns]

# %%
courses_cluster.dtypes
# Out:
# cluster         int64
# item           object
# enrollments     int64
# dtype: object

# %% [markdown]
# _TODO: For each test user, try to recommend any unseen courses based on the popular courses in his/her cluster. You may use an enrollment count threshold (such as larger than 10) to determine if it is a popular course in the cluster_

# %%
# Define a threshold for popular courses enrollment count
popular_threshold = 15

# Iterate over each test user
for user_id in test_users_labelled['user'].unique():
    # Create a subset of the test_users_labelled DataFrame for the current user
    user_subset = test_users_labelled[test_users_labelled['user'] == user_id]
    
    # Get the enrolled courses for the current user
    enrolled_courses = set(user_subset['item'])
    
    # Get the cluster label for the current user
    cluster_id = user_subset['cluster'].iloc[0]
    
    # Find all courses in the same cluster
    courses_in_cluster = set(test_users_labelled[test_users_labelled['cluster'] == cluster_id]['item'])
    
    # Find new/unseen courses for the user
    unseen_courses = courses_in_cluster.difference(enrolled_courses)
    
    # Filter popular courses among the unseen courses
    popular_unseen_courses = set(courses_cluster[(courses_cluster['item'].isin(unseen_courses)) & (courses_cluster['enrollments'] >= popular_threshold)]['item'] )

    # Recommend popular unseen courses to the user
    recommendation_results = popular_unseen_courses.intersection(unseen_courses)
    
    # Print or use the recommendation results as needed
    print(f'Recommend courses for user {user_id}: {recommendation_results}')
# Out:
# Recommend courses for user 1502801: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'CO0201EN', 'LB0101ENv1', 'CB0103EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1609720: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1347188: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 755067: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 538595: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1773079: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 603361: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'DS0101EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 1122903: {'DS0301EN', 'PA0101EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 714414: {'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'BD0111EN', 'BD0121EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1688159: {'BC0101EN', 'BD0211EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'BD0111EN', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 703905: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'DS0103EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 881847: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'CC0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1784245: {'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'BD0131EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1443131: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'DA0101EN', 'SC0101EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'CO0201EN', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1773434: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'PY0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 489692: {'DA0101EN', 'BD0131EN', 'RP0105EN', 'DS0301EN', 'ML0101ENv3', 'CC0101EN', 'ML0103EN', 'BD0211EN', 'BD0141EN', 'ML0115EN', 'DV0101EN', 'ML0151EN', 'CC0103EN', 'DB0101EN', 'CNSC02EN', 'CC0250EN'}
# Recommend courses for user 430274: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1394499: {'BD0131EN', 'ML0101EN', 'SC0101EN', 'BD0115EN', 'BD0141EN', 'PA0101EN', 'ML0120EN', 'WA0101EN'}
# Recommend courses for user 1221910: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'ML0101EN', 'PY0101EN', 'CC0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1636610: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1504635: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN'}
# Recommend courses for user 616284: {'BC0101EN', 'PA0101EN', 'CC0103EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'BD0212EN', 'RP0105EN', 'BC0201EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 462755: {'DS0301EN', 'BC0101EN', 'PA0101EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'BD0115EN', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 902138: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'ML0122ENv1'}
# Recommend courses for user 1102170: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'PY0101EN', 'CC0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 510780: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'DA0101EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 220851: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 952742: {'CC0103EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'BD0115EN', 'DV0151EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 704521: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 517197: {'BC0101EN', 'PA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'DV0151EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1806207: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1648099: {'BD0211EN', 'ML0151EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'PY0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 108541: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1642918: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 601371: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 1199884: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 531408: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 708518: {'BC0101EN', 'BD0211EN', 'SC0101EN', 'BD0115EN', 'ML0120EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1351020: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 472908: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'LB0105ENv1', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 482875: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'DS0105EN', 'CO0201EN', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1541383: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'ML0103EN', 'ML0120EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 877026: {'BD0211EN', 'ML0151EN', 'CC0103EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 755044: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'RP0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 913275: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1275452: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CC0101EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 985429: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1237626: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'BD0111EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 577001: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BC0201EN', 'CO0201EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 981848: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'BD0115EN', 'ML0101ENv3', 'ML0120EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN'}
# Recommend courses for user 1751931: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1378699: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 705065: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 1452505: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 762860: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'BD0212EN', 'BD0121EN', 'CO0201EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1571271: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 767649: {'DS0301EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'DV0151EN', 'BD0212EN', 'RP0105EN', 'BC0201EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'PY0101EN', 'ML0115EN', 'ML0122ENv1'}
# Recommend courses for user 1194679: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1882084: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1506139: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 569052: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1316258: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CNSC02EN', 'RP0101EN', 'BD0115EN', 'ML0120EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1016747: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 696345: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 494226: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 699465: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 886106: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'CB0103EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'ML0115EN', 'ST0101EN'}
# Recommend courses for user 740210: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 690872: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 705746: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'DS0321EN', 'BD0131EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 759038: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1212187: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1715864: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'ML0122ENv1'}
# Recommend courses for user 738131: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 793367: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1271375: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'LB0103ENv1', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'PY0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1405594: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'CC0250EN'}
# Recommend courses for user 266643: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 1194262: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1474331: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1538828: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 669512: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1287782: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'RP0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0120EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1006163: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ML0122ENv1'}
# Recommend courses for user 2021696: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'ML0103EN', 'ML0120EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 970895: {'DS0301EN', 'BC0101EN', 'PA0101EN', 'DA0101EN', 'SC0101EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'BD0121EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1596323: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 979847: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 738953: {'DS0301EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1095855: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 998607: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1521903: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 539916: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'LB0101ENv1', 'CB0103EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'CO0101EN', 'PY0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1404598: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'CC0201EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1563448: {'DS0301EN', 'BC0101EN', 'PA0101EN', 'ML0103EN', 'ML0120EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CL0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 887336: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1206954: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ML0122ENv1'}
# Recommend courses for user 1783867: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1224751: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'PY0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1444838: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 560247: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'LB0105ENv1', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 2004142: {'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 1078030: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 621543: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 684186: {'DS0301EN', 'ML0151EN', 'PA0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'CO0201EN', 'LB0101ENv1', 'CB0103EN', 'ML0120ENv2', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 152320: {'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 578677: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 701650: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1061706: {'BC0101EN', 'ML0151EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'LB0101ENv1', 'CB0103EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'PY0101EN', 'CL0101EN', 'ST0101EN', 'ML0122ENv1'}
# Recommend courses for user 399457: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'CNSC02EN', 'RP0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CC0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 187819: {'BC0101EN', 'CC0103EN', 'CNSC02EN', 'CO0401EN', 'DA0101EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'BC0201EN', 'CO0201EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 2022708: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1355756: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1215047: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'PA0101EN', 'CC0103EN', 'LB0103ENv1', 'CO0401EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1313360: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 952216: {'BD0131EN', 'BD0121EN', 'RP0105EN', 'CO0101EN', 'BC0201EN', 'BD0115EN', 'ML0101ENv3', 'CC0101EN', 'DS0301EN', 'CL0101EN', 'ML0103EN', 'BD0141EN', 'ML0151EN', 'ML0120ENv2', 'ML0122ENv1', 'BD0212EN'}
# Recommend courses for user 1458003: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'RP0101EN', 'SC0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'CO0201EN', 'BD0141EN', 'CC0201EN', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# ...
# Recommend courses for user 1496810: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 1578866: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'ML0103EN', 'ML0120EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 926743: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1887480: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 609064: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 728302: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1646441: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 731074: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'DA0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 2032910: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1911140: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1256661: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'CC0250EN'}
# Recommend courses for user 1870948: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0103EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 1007060: {'BC0101EN', 'ML0151EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'DS0105EN', 'BC0201EN', 'LB0101ENv1', 'DS0103EN', 'ML0120ENv2', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1758996: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 720259: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 884472: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'WA0101EN', 'BD0111EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 1116126: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'DS0103EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 1121636: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 576397: {'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1907898: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 1390057: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1021071: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN'}
# Recommend courses for user 625223: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'RP0101EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0111EN', 'BD0121EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1830259: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ML0122ENv1'}
# Recommend courses for user 676094: {'DS0301EN', 'BC0101EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'SC0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'BD0121EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1076538: {'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'RP0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1871214: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1474724: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1344813: {'DS0301EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN'}
# Recommend courses for user 1847555: {'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'BD0111EN', 'BD0212EN', 'LB0105ENv1', 'BD0121EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1669829: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'RP0101EN', 'DA0101EN', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'BD0111EN', 'RP0105EN', 'DS0105EN', 'CO0201EN', 'DS0103EN', 'ML0120ENv2', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}
# Recommend courses for user 481658: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'WA0101EN', 'LB0105ENv1', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1'}
# Recommend courses for user 1341273: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0103EN', 'DV0101EN', 'CO0301EN', 'LB0105ENv1', 'BD0111EN', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'DS0105EN', 'BC0201EN', 'BD0141EN', 'LB0101ENv1', 'ML0120ENv2', 'DS0103EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'CC0250EN'}
# Recommend courses for user 884271: {'DS0301EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'ML0101EN', 'CO0101EN', 'PY0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'ML0122ENv1', 'CC0250EN'}
# Recommend courses for user 1868084: {'BC0101EN', 'BD0211EN', 'CC0103EN', 'CNSC02EN', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'SC0101EN', 'BD0115EN', 'ML0101ENv3', 'DV0101EN', 'CO0301EN', 'BD0111EN', 'BD0212EN', 'RP0105EN', 'DS0105EN', 'BC0201EN', 'CO0201EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'BD0131EN', 'PY0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN'}
# Recommend courses for user 630511: {'DS0301EN', 'BC0101EN', 'BD0211EN', 'ML0151EN', 'CC0103EN', 'PA0101EN', 'LB0103ENv1', 'CO0401EN', 'RP0101EN', 'DA0101EN', 'ML0101ENv3', 'ML0103EN', 'DV0101EN', 'ML0120EN', 'CO0301EN', 'DV0151EN', 'LB0105ENv1', 'WA0101EN', 'BD0212EN', 'DS0101EN', 'RP0105EN', 'DS0105EN', 'BD0141EN', 'LB0101ENv1', 'CB0103EN', 'CC0201EN', 'ML0120ENv2', 'DS0103EN', 'DS0321EN', 'BD0131EN', 'ML0101EN', 'CO0101EN', 'CC0101EN', 'CL0101EN', 'ML0115EN', 'ST0101EN', 'DB0101EN', 'BD0101EN', 'ML0122ENv1'}

# %% [markdown]
# With the recommendation results, we also need to write some analytic code to answer the following two questions:

# %% [markdown]
# - On average, how many new/unseen courses have been recommended to each user?
# - What are the most frequently recommended courses? Return the top-10 commonly recommended courses across all users.

# %% [markdown]
# For example, suppose we have only 3 test users, each user receives the following recommendations:

# %% [markdown]
# - User1: ['course1', 'course2']
# - User2: ['course3', 'course4']
# - User3: ['course3', 'course4', 'course5']

# %% [markdown]
# Then, the average recommended courses per user is $(2 + 2 + 3) / 3 = 2.33$. The top-2 recommended courses are: `course3`: 2 times, and `course4`: 2 times.

# %% [markdown]
# Note that the answers will depend on how you compute the popular courses for each cluster. A lower threshold yields more recommended courses but with smaller confidence so that some test users may receive very long course recommendation lists and feel overwhelmed.
#
# Ideally, we should limit the maximum course recommendations for each user to be less than 20 courses per user.

# %% [markdown]
# ### Explore other clustering algorithms

# %% [markdown]
# There are many other clustering algorithms such as `DBSCAN` and `Hierarchical Clustering`. We can try them on the user profile feature vectors and compare the results with K-means.

# %% [markdown]
# ### Summary

# %% [markdown]
# We have applied clustering algorithms to group users with similar interests and also tried PCA to reduce the dimensions of user feature vectors.
#
# Furthermore, with each user finding its learning interest group, we have also implemented clustering-based course recommender system to make recommendations based on his/her group members' popular courses choices.
